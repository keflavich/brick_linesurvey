# %%
import pyspeckit
import glob
# Out:
# block_reduce was moved to the astropy.nddata.blocks module.  Please update your import statement.

# %%
fns = glob.glob("/orange/adamginsburg/brick_alma_linesurvey/2019.1.00092.S/imaging_results/spectra/source_ab*clean_2sigma_n50000_masked*max.fits")

# %%
fns
# Out:
# ['/orange/adamginsburg/brick_alma_linesurvey/2019.1.00092.S/imaging_results/spectra/source_ab_104_spw25_clean_2sigma_n50000_masked_3sigma_pbmask0p18.max.fits',
#  '/orange/adamginsburg/brick_alma_linesurvey/2019.1.00092.S/imaging_results/spectra/source_ab_102_spw23_clean_2sigma_n50000_masked_3sigma_pbmask0p18.max.fits',
#  '/orange/adamginsburg/brick_alma_linesurvey/2019.1.00092.S/imaging_results/spectra/source_ab_129_spw67_clean_2sigma_n50000_masked_3sigma_pbmask0p18.max.fits',
#  '/orange/adamginsburg/brick_alma_linesurvey/2019.1.00092.S/imaging_results/spectra/source_ab_99_spw25_clean_2sigma_n50000_masked_3sigma_pbmask0p18.max.fits',
#  '/orange/adamginsburg/brick_alma_linesurvey/2019.1.00092.S/imaging_results/spectra/source_ab_255_spw87_clean_2sigma_n50000_masked_3sigma_pbmask0p18.max.fits',
#  '/orange/adamginsburg/brick_alma_linesurvey/2019.1.00092.S/imaging_results/spectra/source_ab_139_spw71_clean_2sigma_n50000_masked_3sigma_pbmask0p18.max.fits',
# ...

# %%
spectra = pyspeckit.Spectra(fns)
# Out:
# INFO: Creating spectra [pyspeckit.spectrum.classes]
# INFO: Concatenating data [pyspeckit.spectrum.classes]

# %%
for sp in spectra:
    sp.data -= np.nanmedian(sp.data)

# %%
spectra = pyspeckit.Spectra([sp for sp in spectra])
# Out:
# INFO: Creating spectra [pyspeckit.spectrum.classes]
# INFO: Concatenating data [pyspeckit.spectrum.classes]

# %%
spectra.plotter(xmax=115e9)
# Out:
# support for accessing str attributes such as 'lower' from PhysicalType instances is deprecated since 4.3 and will be removed in a subsequent release.
# support for accessing str attributes such as 'title' from PhysicalType instances is deprecated since 4.3 and will be removed in a subsequent release.

# %%
spectra.plotter(xmin=125e9, xmax=153e9)
# Out:
# support for accessing str attributes such as 'lower' from PhysicalType instances is deprecated since 4.3 and will be removed in a subsequent release.
# support for accessing str attributes such as 'title' from PhysicalType instances is deprecated since 4.3 and will be removed in a subsequent release.

# %%
spectra.plotter()
# Out:
# support for accessing str attributes such as 'lower' from PhysicalType instances is deprecated since 4.3 and will be removed in a subsequent release.
# support for accessing str attributes such as 'title' from PhysicalType instances is deprecated since 4.3 and will be removed in a subsequent release.

# %%
spectra.plotter(xmin=242e9,)
# Out:
# support for accessing str attributes such as 'lower' from PhysicalType instances is deprecated since 4.3 and will be removed in a subsequent release.
# support for accessing str attributes such as 'title' from PhysicalType instances is deprecated since 4.3 and will be removed in a subsequent release.
